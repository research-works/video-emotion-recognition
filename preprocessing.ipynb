# %%
import utils.data_util as data_util

# %%
data_util.preprocess_audio_data()
# Out:
# -16.npy
# 03-01-05-01-02-01-16.wav
# Saving to file : /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RAVDESS/Audio_preprocessing_output/Actor_16/03-01-05-01-02-01-16.npy
# 03-01-03-01-01-01-16.wav
# Saving to file : /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RAVDESS/Audio_preprocessing_output/Actor_16/03-01-03-01-01-01-16.npy
# 03-01-07-01-02-01-16.wav
# Saving to file : /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RAVDESS/Audio_preprocessing_output/Actor_16/03-01-07-01-02-01-16.npy
# 03-01-06-01-01-01-16.wav
# Saving to file : /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RAVDESS/Audio_preprocessing_output/Actor_16/03-01-06-01-01-01-16.npy
# 03-01-06-01-01-02-16.wav
# Saving to file : /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RAVDESS/Audio_preprocessing_output/Actor_16/03-01-06-01-01-02-16.npy
# 03-01-05-02-01-02-16.wav
# ...
