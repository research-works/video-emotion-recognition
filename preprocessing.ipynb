# %%
import os
hostname = os.popen("hostname").read().split("\n")[0]
if(hostname != "reckoner1429-Predator-PH315-52"):
    from google.colab import drive
    from google.colab import drive
    drive.mount('/content/gdrive')

    ! chmod 755 "/content/gdrive/My Drive/collab-var.sh"
    ! "/content/gdrive/My Drive/collab-var.sh"
    # %cd "/content/gdrive/My Drive/github/video-emotion-recognition"

# %%
import utils.preprocess_util as preprocess_util

# %%
dataset = preprocess_util.RML()
dataset.process_video()
# Out:
# tated_frames/rotated_fe3/frame150.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame0.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame10.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame190.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame70.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame60.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame50.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame40.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame30.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame160.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame100.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame90.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame130.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame20.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame180.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame110.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame120.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame170.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe3/frame140.jpg
# size: 196608
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# i: 90 aux: 100
# inner
# i: 100 aux: 110
# inner
# i: 110 aux: 120
# inner
# i: 120 aux: 130
# inner
# i: 130 aux: 140
# inner
# i: 140 aux: 150
# inner
# i: 150 aux: 160
# inner
# i: 160 aux: 170
# inner
# i: 170 aux: 180
# inner
# i: 180 aux: 190
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# outer
# i: 0 aux: 10
# inner
# outer
# di1.avi
# path of videos: /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/VideoData/s1/f1eng/di1.avi
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# oof
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/frames/data_di1
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame80.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame150.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame0.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame10.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame70.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame60.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame50.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame40.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame30.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame160.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame100.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame90.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame130.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame20.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame180.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame110.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame120.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame170.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di1/frame140.jpg
# size: 196608
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# i: 90 aux: 100
# inner
# i: 100 aux: 110
# inner
# i: 110 aux: 120
# inner
# i: 120 aux: 130
# inner
# i: 130 aux: 140
# inner
# i: 140 aux: 150
# inner
# i: 150 aux: 160
# inner
# i: 160 aux: 170
# inner
# i: 170 aux: 180
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# outer
# i: 0 aux: 10
# inner
# outer
# fe2.avi
# path of videos: /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/VideoData/s1/f1eng/fe2.avi
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# oof
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/frames/data_fe2
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame80.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame150.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame0.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame10.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame70.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame60.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame50.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame40.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame30.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame160.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame100.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame90.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame130.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame20.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame110.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame120.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame170.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_fe2/frame140.jpg
# size: 196608
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# i: 90 aux: 100
# inner
# i: 100 aux: 110
# inner
# i: 110 aux: 120
# inner
# i: 120 aux: 130
# inner
# i: 130 aux: 140
# inner
# i: 140 aux: 150
# inner
# i: 150 aux: 160
# inner
# i: 160 aux: 170
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# outer
# i: 0 aux: 10
# inner
# outer
# di3.avi
# path of videos: /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/VideoData/s1/f1eng/di3.avi
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# oof
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/frames/data_di3
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame80.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame150.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame0.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame10.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame70.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame60.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame50.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame40.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame30.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame160.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame100.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame90.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame130.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame20.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame180.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame110.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame120.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame170.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di3/frame140.jpg
# size: 196608
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# i: 90 aux: 100
# inner
# i: 100 aux: 110
# inner
# i: 110 aux: 120
# inner
# i: 120 aux: 130
# inner
# i: 130 aux: 140
# inner
# i: 140 aux: 150
# inner
# i: 150 aux: 160
# inner
# i: 160 aux: 170
# inner
# i: 170 aux: 180
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# outer
# i: 0 aux: 10
# inner
# outer
# di4.avi
# path of videos: /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/VideoData/s1/f1eng/di4.avi
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# (240, 320, 3)
# oof
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/frames/data_di4
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame80.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame150.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame0.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame10.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame190.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame70.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame60.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame50.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame40.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame30.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame160.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame100.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame90.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame130.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame20.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame180.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame110.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame120.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame170.jpg
# size: 196608
# /home/reckoner1429/Documents/projects/video-emotion-recognition/data/RML/Video_preprocessing_output/s1/rotated_frames/rotated_di4/frame140.jpg
# size: 196608
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# i: 90 aux: 100
# inner
# i: 100 aux: 110
# inner
# i: 110 aux: 120
# inner
# i: 120 aux: 130
# inner
# i: 130 aux: 140
# inner
# i: 140 aux: 150
# inner
# i: 150 aux: 160
# inner
# i: 160 aux: 170
# inner
# i: 170 aux: 180
# inner
# i: 180 aux: 190
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# i: 40 aux: 50
# inner
# i: 50 aux: 60
# inner
# i: 60 aux: 70
# inner
# i: 70 aux: 80
# inner
# i: 80 aux: 90
# inner
# outer
# i: 0 aux: 10
# inner
# i: 10 aux: 20
# inner
# i: 20 aux: 30
# inner
# i: 30 aux: 40
# inner
# outer
# i: 0 aux: 10
# inner
# outer
